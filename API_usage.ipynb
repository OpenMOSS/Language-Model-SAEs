# %% [markdown]
# ### GPT

# %%
import unicodedata
from openai import OpenAI
client = OpenAI(
    api_key="sk-gUy1pgf3sJBTrjm4Fc9588558d72484f992fA154E012185c",
    base_url="https://api.chatgptid.net/v1"
)

completion = client.chat.completions.create(
    messages=[
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "你好!"}
  ],
    # model="gpt-3.5-turbo-1106",
    model = "gpt-4o",
)

message = completion.choices[0].message
content = unicodedata.normalize('NFKC', message.content)
print(content)

# %% [markdown]
# ### Claude

# %%
import http.client
import json
import os
os.environ['ANTHROPIC_API_KEY'] = "sk-d23HblWLjgYi0OR2Bb004e8bA8594c21Bd5a25Bd60D31d61"

conn = http.client.HTTPSConnection("api3.apifans.com")
payload = json.dumps({
  # "model": "claude-3-sonnet-20240229", "claude-3-haiku-20240307" "claude-3-opus-20240229", claude-3-5-sonnet-20240620
  "model": "claude-3-opus-20240229",
  "max_tokens": 1024,
  "messages": [
    {
      "role": "user",
      "content": '''1+1=?'''
    }
  ]
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Bearer sk-d23HblWLjgYi0OR2Bb004e8bA8594c21Bd5a25Bd60D31d61'
}
conn.request("POST", "/v1/chat/completions", payload, headers)
res = conn.getresponse()
data = res.read()
data_dict = json.loads(data.decode("utf-8"))
content = data_dict # ["choices"][0]["message"]["content"]
print(content.get("choices")[0].get("message").get("content"))
# Out:
#  2

# %% [markdown]
# ### Qwen

# %%
import requests
import json

url = "https://api.siliconflow.cn/v1/chat/completions"

payload = {
    "model": "Qwen/Qwen2-72B-Instruct",
    "messages": [
        {
            "role": "user",
            "content": "SiliconCloud公测上线，每用户送3亿token 解锁开源大模型创新能力。对于整个大模型应用领域带来哪些改变？"
        }
    ]
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Bearer sk-udlztdflpbbxtarajggqesnmebzjpdauwakklqcnegvfadcp"
}

response = requests.post(url, json=payload, headers=headers)

response_dict = json.loads(response.text)
result = response_dict.get("choices")[0].get("message").get("content")
print(result)
# Out:
# SiliconCloud公测上线并赠送大量token以解锁开源大模型创新能力的举措，可能会为整个大模型应用领域带来以下几个方面的显著改变：
#
# 1. **成本门槛降低：**通过赠送token，SiliconCloud实际上降低了开发者和研究人员访问和使用先进大模型的成本门槛。这可能会吸引更多的创新者进入该领域，从而加速技术的迭代和应用的多样化。
#
# 2. **促进模型的开放和共享：**开源大模型的推广使用鼓励了模型的共享和改进。这不仅能够促进学术界与工业界之间的知识交流，还能加速模型的优化和创新，提高大模型的性能和适用性。
#
# 3. **加速行业应用：**随着大模型的使用更加普及，各行各业都可以利用这些模型来提升其产品和服务。例如，医疗、金融、教育、娱乐等行业可以借助大模型进行定制化开发，从而提供更加个性化和智能的服务。
#
# 4. **推动AI民主化：**这一举措有助于AI的民主化，使得更多的人能够接触到和利用先进的人工智能技术。这对于缩小技术鸿沟，推动全球科技创新和经济发展具有重要意义。
#
# 5. **挑战和风险管理：**大模型的广泛应用也会带来数据隐私、模型安全性、伦理道德等挑战。因此，这也要求行业和监管机构共同努力，建立相应的规范和标准，以保证技术的健康发展。
#
# 6. **创新生态构建：**通过鼓励创新，SiliconCloud能够让更多的创业者和开发者围绕大模型构建创新应用和服务，形成一个良性的创新生态，推动人工智能行业形成更加丰富的应用生态圈。
#
# 总的来说，SiliconCloud此举在推动人工智能技术的普及、创新和应用方面有着积极的作用，对于整个大模型应用领域来说，这可能会开启一个全新的发展阶段。

# %%
import os
def get_response():
    client = OpenAI(
        api_key='sk-c1982d994971419ea023b0d70ed085e0', # 如果您没有配置环境变量，请在此处用您的API Key进行替换
        base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",  # 填写DashScope服务的base_url
    )
    completion = client.chat.completions.create(
        model="qwen-plus",
        messages=[{'role': 'system', 'content': 'You are a helpful assistant.'},
                  {'role': 'user', 'content': '你是谁？'}]
        )
    # print(completion.model_dump_json())
    print(completion.choices[0].message.content)
    return completion

completion = get_response()
# Out:
# 我是来自阿里云的大规模语言模型，我叫通义千问。

# %% [markdown]
# ### Deepseek

# %%
from openai import OpenAI

client = OpenAI(api_key="sk-7e23a3f07c67466bb5d766401c142d4b", base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Hello"},
    ],
    stream=False
)

print(response.choices[0].message.content)
# print(completion.model_dump_json())
# Out:
# Hello! How can I assist you today?
