# %%
from datasets import load_from_disk

# 指定.arrow文件路径
file_path = "./test"

# 使用 datasets 库加载.arrow文件
dataset = load_from_disk(file_path)
saved_dict = dataset.to_dict()

# %%
print(saved_dict)
# Out:
# {'34_top_10_negative_logits': [-22.769367218017578, -21.780010223388672, -21.11591339111328, -20.611976623535156, -20.48258399963379, -20.032543182373047, -19.468822479248047, -19.14297103881836, -18.572383880615234, -18.389225006103516], '34_top_10_negative_tokens': ['ĠRebell', 'anthrop', 'ĠLeilan', 'forth', 'advertising', 'Ġç¥ŀ', 'ĠMetatron', 'ĠãĤµãĥ¼ãĥĨãĤ£ãĥ¯ãĥ³', 'BuyableInstoreAndOnline', 'ä»£'], '34_top_10_positive_logits': [17.831562042236328, 18.20749282836914, 18.766010284423828, 18.81629180908203, 19.051124572753906, 19.440673828125, 19.64211654663086, 21.7104434967041, 22.527950286865234, 25.231998443603516], '34_top_10_positive_tokens': ['azor', 'ĠguiActiveUn', 'WER', 'erto', 'unci', 'anooga', 'sonian', 'irtual', 'obook', 'emort'], '36_top_10_negative_logits': [-32.9813117980957, -31.37259292602539, -28.91265296936035, -26.613510131835938, -26.496641159057617, -25.751224517822266, -25.56479835510254, -25.33828353881836, -25.297595977783203, -25.204465866088867], '36_top_1
# ...

# %%
print(saved_dict['34' + '_top_10_negative_logits'])
# Out:
# [-22.769367218017578, -21.780010223388672, -21.11591339111328, -20.611976623535156, -20.48258399963379, -20.032543182373047, -19.468822479248047, -19.14297103881836, -18.572383880615234, -18.389225006103516]
