# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch


def filter_and_pad_tensor_foro(tokens, activation):
    original_length = len(tokens)
    tokens_list = tokens.tolist()
    activation_list = activation.tolist()
    indices_to_remove = set()

    k = len(tokens) - 1
    pad_token_id = 128001
    if tokens[k] >= 128000:
        pad_token_id = tokens[k]
        while k >= 0 and tokens[k] == pad_token_id:
            k -= 1

    i = 0
    while i <= k:
        if tokens_list[i] >= 128000:
            indices_to_remove.add(i)
        i += 1

    filtered_tokens_list = [tokens_list[idx] for idx in range(len(tokens_list)) if idx not in indices_to_remove]
    filtered_activation_list = [activation_list[idx] for idx in range(len(tokens_list)) if idx not in indices_to_remove]

    num_to_pad = original_length - len(filtered_tokens_list)
    if num_to_pad > 0:
        filtered_tokens_list.extend([filtered_tokens_list[-1]] * num_to_pad)
        filtered_activation_list.extend([filtered_activation_list[-1]] * num_to_pad)

    return torch.tensor(filtered_tokens_list), torch.tensor(filtered_activation_list)


def filter_and_pad_tensor_fori(tokens, activation, otemplate):
    original_length = len(tokens)
    tokens_list = tokens.tolist()
    activation_list = activation.tolist()
    o_list = otemplate.tolist()
    objlen = len(o_list)
    indices_to_remove = set()

    k = len(tokens) - 1
    pad_token_id = 128009
    if tokens[k] >= 128000:
        pad_token_id = tokens[k]
        while k >= 0 and tokens[k] == pad_token_id:
            k -= 1

    j = 0
    for i in range(k + 1):
        if j < objlen and tokens_list[i] == o_list[j]:
            j += 1
        else:
            indices_to_remove.add(i)

    filtered_tokens_list = [tokens_list[idx] for idx in range(len(tokens_list)) if idx not in indices_to_remove]
    filtered_activation_list = [activation_list[idx] for idx in range(len(tokens_list)) if idx not in indices_to_remove]

    num_to_pad = original_length - len(filtered_tokens_list)
    if num_to_pad > 0:
        filtered_tokens_list.extend([filtered_tokens_list[-1]] * num_to_pad)
        filtered_activation_list.extend([filtered_activation_list[-1]] * num_to_pad)

    return torch.tensor(filtered_tokens_list), torch.tensor(filtered_activation_list)


def filter_and_pad_tensor_forb(tokens, activation, otemplate):
    original_length = len(tokens)
    tokens_list = tokens.tolist()
    activation_list = activation.tolist()
    o_list = otemplate.tolist()
    objlen = len(o_list)
    indices_to_remove = set()

    k = len(tokens) - 1
    pad_token_id = 128001
    if tokens[k] >= 128000:
        pad_token_id = tokens[k]
        while k >= 0 and tokens[k] == pad_token_id:
            k -= 1

    j = 0
    for i in range(k + 1):
        if j < objlen and tokens_list[i] == o_list[j]:
            j += 1
        else:
            indices_to_remove.add(i)

    filtered_tokens_list = [tokens_list[idx] for idx in range(len(tokens_list)) if idx not in indices_to_remove]
    filtered_activation_list = [activation_list[idx] for idx in range(len(tokens_list)) if idx not in indices_to_remove]

    num_to_pad = original_length - len(filtered_tokens_list)
    if num_to_pad > 0:
        filtered_tokens_list.extend([filtered_tokens_list[-1]] * num_to_pad)
        filtered_activation_list.extend([filtered_activation_list[-1]] * num_to_pad)

    return torch.tensor(filtered_tokens_list), torch.tensor(filtered_activation_list)

# %%
import os

from safetensors.torch import load_file, save_file

# %%
def process_file(args):
    input_folder, output_folder, filename, model_name = args
    input_path = os.path.join(input_folder, filename)
    output_path = os.path.join(output_folder, filename)
    if model_name == "o":
        filter_func = filter_and_pad_tensor_foro
    elif model_name == "i":
        filter_func = filter_and_pad_tensor_fori
    elif model_name == "b":
        filter_func = filter_and_pad_tensor_forb
    else:
        return f"there is no such model : {model_name}"

    if os.path.exists(input_path):
        tensor_data = load_file(input_path)

        tokens = tensor_data["tokens"][0]
        activation = tensor_data["activation"][0]

        tensor_data["tokens"][0], tensor_data["activation"][0] = filter_func(tokens, activation)

        save_file(tensor_data, output_path)
        return f"Processed and saved: {output_path}"
    else:
        return f"File not found: {input_path}"

# %%
from multiprocessing import Pool, cpu_count


def main(
    input_folder="/inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post",
    output_folder="/inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15-f/blocks.15.hook_resid_post",
):
    os.makedirs(output_folder, exist_ok=True)

    all_files = [f"shard-{shard}-chunk-{chunk:08d}.safetensors" for shard in range(8) for chunk in range(1557)]

    cpu_cores = min(cpu_count(), 16)
    with Pool(cpu_cores) as pool:
        results = pool.map(process_file, [(input_folder, output_folder, f, "o") for f in all_files])

    for result in results:
        print(result)


main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a>     for result in results:
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>         print(result)
# ---> <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> main()
#
# /inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> cpu_cores = min(cpu_count(), 16)
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> with Pool(cpu_cores) as pool:
# ---> <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     results = pool.map(process_file, [(input_folder, output_folder, f, 'o') for f in all_files])
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> for result in results:
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>     print(result)
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/.local/share/uv/python/cpython-3.12.8-linux-x86_64-gnu/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
input_folder = (
    "/inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post"
)
output_folder = "/inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15-f/blocks.15.hook_resid_post"
os.makedirs(output_folder, exist_ok=True)

for shard in range(8):
    for chunk in range(1557):
        filename = f"shard-{shard}-chunk-{chunk:08d}.safetensors"
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        if os.path.exists(input_path):
            tensor_data = load_file(input_path)

            tokens = tensor_data["tokens"][0]
            activation = tensor_data["activation"][0]

            tensor_data["tokens"][0], tensor_data["activation"][0] = filter_and_pad_tensor_foro(tokens, activation)

            save_file(tensor_data, output_path)
            print(f"Processed and saved: {output_path}")
        else:
            print(f"File not found: {input_path}")
# Out:
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000000.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000001.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000002.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000003.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000004.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000005.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000006.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000007.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000008.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000009.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000010.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000011.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000012.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000013.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000014.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000015.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000016.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000017.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000018.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000019.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000020.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000021.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000022.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000023.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000024.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000025.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000026.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000027.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000028.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000029.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000030.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000031.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000032.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000033.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000034.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000035.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000036.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000037.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000038.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000039.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000040.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000041.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000042.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000043.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000044.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000045.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000046.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000047.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000048.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000049.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000050.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000051.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000052.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000053.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000054.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000055.safetensors
# Processed and saved: /inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/blocks.15.hook_resid_post/shard-0-chunk-00000056.safetensors
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> tokens = tensor_data['tokens'][0]
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> activation = tensor_data['activation'][0]
# ---> <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> tensor_data['tokens'][0],tensor_data['activation'][0] = filter_and_pad_tensor_foro(tokens,activation)
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> save_file(tensor_data, output_path)
#      <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> print(f"Processed and saved: {output_path}")
#
# /inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> original_length = len(tokens)
#       <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> tokens_list = tokens.tolist()
# ----> <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> activation_list = activation.tolist()
#       <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> indices_to_remove = set()
#       <a href='vscode-notebook-cell://notebook-inspire.sii.edu.cn/inspire/hdd/ws-8207e9e2-e733-4eec-a475-cfa1c36480ba/embodied-multimodality/public/zfhe/jiaxing_projects/Language-Model-SAEs/exp/programmatic/remove_template_final.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> k = len(tokens) - 1
#
# KeyboardInterrupt:

# %%
print(
    os.path.exists(
        "/inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15/shard-0-chunk-00000000.safetensors"
    )
)
print(os.path.exists("/inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15"))
print(os.listdir("/inspire/hdd/global_user/hezhengfu-240208120186/jiaxing_activations/reasondata-o-2d-l15"))
# Out:
# False
# True
# ['blocks.15.hook_resid_post']
